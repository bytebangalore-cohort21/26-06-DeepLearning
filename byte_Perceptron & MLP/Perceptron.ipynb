# %%
import numpy as np

# %% [markdown]
# ## Perceptron Model
#
# To make a prediction using the perceptron we need an activation function, and based on the activation, we will predict a class. In this way, the perceptron is very similar to linear/logistic regression in that the prediction is a weighted sum of inputs.
#
# **activation = sum(weight_i * x_i) + bias**
#
# **prediction = 1.0 if activation >0.0 else 0.0**

# %%
def predict(row, weights):
    activation = weights[0]
    #print(len(row)-1)
    for i in range(len(row)-1):
        #print(row[i])
        activation = activation +  weights[i + 1] * row[i]
        #print(activation)
    if activation >0.0:
        return 1.0
    else:
        return 0.0
 

dataset = [[2.7810836,2.550537003,0],
    [1.465489372,2.362125076,0],
    [3.396561688,4.400293529,0],
    [1.38807019,1.850220317,0],
    [3.06407232,3.005305973,0],
    [7.627531214,2.759262235,1],
    [5.332441248,2.088626775,1],
    [6.922596716,1.77106367,1],
    [8.675418651,-0.242068655,1],
    [7.673756466,3.508563011,1]]
weights = [-0.1, 0.8, -0.6]
for row in dataset:
    prediction = predict(row, weights)
    print("Expected=%d, Predicted=%d" % (row[-1], prediction))
# Out:
# Expected=0, Predicted=1
# Expected=0, Predicted=0
# Expected=0, Predicted=0
# Expected=0, Predicted=0
# Expected=0, Predicted=1
# Expected=1, Predicted=1
# Expected=1, Predicted=1
# Expected=1, Predicted=1
# Expected=1, Predicted=1
# Expected=1, Predicted=1

# %% [markdown]
# We now move to updating weights and the bias
#
# **Weight update**: w(t+1)= w(t) + learning_rate * (expected(t) - predicted(t)) * x(t)
#
# **Bias update:** bias(t+1) = bias(t) + learning_rate * (expected(t) - predicted(t))
#
# We need three loops here:
#
# - Loop over each iteration.
# - Loop over each row in the training data for an iteration.
# - Loop over each weight and update it for a row in an iteration.

# %%
def train_weights(train, alpha, iterations,weights):
    for i in range(iterations):
        sum_error = 0.0
        for row in train:
            prediction = predict(row, weights)
            error = row[-1] - prediction
            #linear activation function's cost function
            sum_error += error**2
            #updating bias
            weights[0] = weights[0] + alpha * error 
            for j in range(len(row)-1):
                #update coeffts
                weights[j + 1] = weights[j + 1] + alpha * error * row[j]
                #print(weights)
        print('iteration=%d, alpha=%.3f, error=%.3f' % (i, alpha, sum_error))
    return weights

# %%
# Calculate weights
dataset = [[2.7810836,2.550537003,0],
	[1.465489372,2.362125076,0],
	[3.396561688,4.400293529,0],
	[1.38807019,1.850220317,0],
	[3.06407232,3.005305973,0],
	[7.627531214,2.759262235,1],
	[5.332441248,2.088626775,1],
	[6.922596716,1.77106367,1],
	[8.675418651,-0.242068655,1],
	[7.673756466,3.508563011,1]]
alpha = 0.1
iteratinos = 100
weights = train_weights(dataset, alpha, iteratinos,[-0.1, 0.8, -0.6])
print("\n")
print("Final Weights:",(weights))
print("Expected=%d, Predicted=%d" % (row[-1], prediction))
# Out:
# iteration=0, alpha=0.100, error=1.000
# iteration=1, alpha=0.100, error=0.000
# iteration=2, alpha=0.100, error=0.000
# iteration=3, alpha=0.100, error=0.000
# iteration=4, alpha=0.100, error=0.000
# iteration=5, alpha=0.100, error=0.000
# iteration=6, alpha=0.100, error=0.000
# iteration=7, alpha=0.100, error=0.000
# iteration=8, alpha=0.100, error=0.000
# iteration=9, alpha=0.100, error=0.000
# iteration=10, alpha=0.100, error=0.000
# iteration=11, alpha=0.100, error=0.000
# iteration=12, alpha=0.100, error=0.000
# iteration=13, alpha=0.100, error=0.000
# iteration=14, alpha=0.100, error=0.000
# iteration=15, alpha=0.100, error=0.000
# iteration=16, alpha=0.100, error=0.000
# iteration=17, alpha=0.100, error=0.000
# iteration=18, alpha=0.100, error=0.000
# iteration=19, alpha=0.100, error=0.000
# iteration=20, alpha=0.100, error=0.000
# iteration=21, alpha=0.100, error=0.000
# iteration=22, alpha=0.100, error=0.000
# iteration=23, alpha=0.100, error=0.000
# iteration=24, alpha=0.100, error=0.000
# iteration=25, alpha=0.100, error=0.000
# iteration=26, alpha=0.100, error=0.000
# iteration=27, alpha=0.100, error=0.000
# iteration=28, alpha=0.100, error=0.000
# iteration=29, alpha=0.100, error=0.000
# iteration=30, alpha=0.100, error=0.000
# iteration=31, alpha=0.100, error=0.000
# iteration=32, alpha=0.100, error=0.000
# iteration=33, alpha=0.100, error=0.000
# iteration=34, alpha=0.100, error=0.000
# iteration=35, alpha=0.100, error=0.000
# iteration=36, alpha=0.100, error=0.000
# iteration=37, alpha=0.100, error=0.000
# iteration=38, alpha=0.100, error=0.000
# iteration=39, alpha=0.100, error=0.000
# iteration=40, alpha=0.100, error=0.000
# iteration=41, alpha=0.100, error=0.000
# iteration=42, alpha=0.100, error=0.000
# iteration=43, alpha=0.100, error=0.000
# iteration=44, alpha=0.100, error=0.000
# iteration=45, alpha=0.100, error=0.000
# iteration=46, alpha=0.100, error=0.000
# iteration=47, alpha=0.100, error=0.000
# iteration=48, alpha=0.100, error=0.000
# iteration=49, alpha=0.100, error=0.000
# iteration=50, alpha=0.100, error=0.000
# iteration=51, alpha=0.100, error=0.000
# iteration=52, alpha=0.100, error=0.000
# iteration=53, alpha=0.100, error=0.000
# iteration=54, alpha=0.100, error=0.000
# iteration=55, alpha=0.100, error=0.000
# iteration=56, alpha=0.100, error=0.000
# iteration=57, alpha=0.100, error=0.000
# iteration=58, alpha=0.100, error=0.000
# iteration=59, alpha=0.100, error=0.000
# iteration=60, alpha=0.100, error=0.000
# iteration=61, alpha=0.100, error=0.000
# iteration=62, alpha=0.100, error=0.000
# iteration=63, alpha=0.100, error=0.000
# iteration=64, alpha=0.100, error=0.000
# iteration=65, alpha=0.100, error=0.000
# iteration=66, alpha=0.100, error=0.000
# iteration=67, alpha=0.100, error=0.000
# iteration=68, alpha=0.100, error=0.000
# iteration=69, alpha=0.100, error=0.000
# iteration=70, alpha=0.100, error=0.000
# iteration=71, alpha=0.100, error=0.000
# iteration=72, alpha=0.100, error=0.000
# iteration=73, alpha=0.100, error=0.000
# iteration=74, alpha=0.100, error=0.000
# iteration=75, alpha=0.100, error=0.000
# iteration=76, alpha=0.100, error=0.000
# iteration=77, alpha=0.100, error=0.000
# iteration=78, alpha=0.100, error=0.000
# iteration=79, alpha=0.100, error=0.000
# iteration=80, alpha=0.100, error=0.000
# iteration=81, alpha=0.100, error=0.000
# iteration=82, alpha=0.100, error=0.000
# iteration=83, alpha=0.100, error=0.000
# iteration=84, alpha=0.100, error=0.000
# iteration=85, alpha=0.100, error=0.000
# iteration=86, alpha=0.100, error=0.000
# iteration=87, alpha=0.100, error=0.000
# iteration=88, alpha=0.100, error=0.000
# iteration=89, alpha=0.100, error=0.000
# iteration=90, alpha=0.100, error=0.000
# iteration=91, alpha=0.100, error=0.000
# iteration=92, alpha=0.100, error=0.000
# iteration=93, alpha=0.100, error=0.000
# iteration=94, alpha=0.100, error=0.000
# iteration=95, alpha=0.100, error=0.000
# iteration=96, alpha=0.100, error=0.000
# iteration=97, alpha=0.100, error=0.000
# iteration=98, alpha=0.100, error=0.000
# iteration=99, alpha=0.100, error=0.000
#
#
# Final Weights: [-0.2, 0.52189164, -0.8550537003]
# Expected=1, Predicted=1

# %%
from sklearn.linear_model import Perceptron as pcp

import pandas as pd

# %%
df = pd.read_csv("Telecom_Train.csv")

# %%
df
# Out:
#      State  Account_Length  Area_Code  Phone_No International_Plan  \
# 0       KS             128        415   3824657                 no
# 1       OH             107        415   3717191                 no
# 2       NJ             137        415   3581921                 no
# 3       OH              84        408   3759999                yes
# 4       OK              75        415   3306626                yes
# 5       AL             118        510   3918027                yes
# 6       MA             121        510   3559993                 no
# 7       MO             147        415   3299001                yes
# 8       LA             117        408   3354719                 no
# 9       WV             141        415   3308173                yes
# 10      IN              65        415   3296603                 no
# 11      RI              74        415   3449403                 no
# 12      IA             168        408   3631107                 no
# 13      MT              95        510   3948006                 no
# 14      IA              62        415   3669238                 no
# 15      NY             161        415   3517269                 no
# 16      ID              85        408   3508884                 no
# 17      VT              93        510   3862923                 no
# 18      VA              76        510   3562992                 no
# 19      TX              73        415   3732782                 no
# 20      FL             147        415   3965800                 no
# 21      CO              77        408   3937984                 no
# 22      AZ             130        415   3581958                 no
# 23      SC             111        415   3502565                 no
# 24      VA             132        510   3434696                 no
# 25      NE             174        415   3313698                 no
# 26      WY              57        408   3573817                 no
# 27      MT              54        408   4186412                 no
# 28      MO              20        415   3532630                 no
# 29      HI              49        510   4107789                 no
# ...    ...             ...        ...       ...                ...
# 3303    WI             114        415   3737308                 no
# 3304    IL              71        510   3307137                yes
# 3305    IN              58        415   4068445                 no
# 3306    AL             106        408   4045283                 no
# 3307    OK             172        408   3983632                 no
# 3308    IA              45        415   3995763                 no
# 3309    VT             100        408   3409449                yes
# 3310    NY              94        415   3631123                 no
# 3311    LA             128        415   3612170                 no
# 3312    SC             181        408   4066304                 no
# 3313    ID             127        408   3925090                 no
# 3314    MO              89        415   3737713                 no
# 3315    ME             149        415   3921376                 no
# 3316    MS             103        510   3906388                 no
# 3317    SD             163        415   3797290                yes
# 3318    OK              52        415   3979928                 no
# 3319    WY              89        415   3786924                 no
# 3320    GA             122        510   4115677                yes
# 3321    VT              60        415   4002738                 no
# 3322    MD              62        408   4091856                 no
# 3323    IN             117        415   3625899                 no
# 3324    WV             159        415   3771164                 no
# 3325    OH              78        408   3688555                 no
# 3326    OH              96        415   3476812                 no
# 3327    SC              79        415   3483830                 no
# 3328    AZ             192        415   4144276                 no
# 3329    WV              68        415   3703271                 no
# 3330    RI              28        510   3288230                 no
# 3331    CT             184        510   3646381                yes
# 3332    TN              74        415   4004344                 no
#
#      Voice_Mail_Plan  No_Vmail_Messages  Total_Day_minutes  Total_Day_Calls  \
# 0                yes                 25              265.1              110
# 1                yes                 26              161.6              123
# 2                 no                  0              243.4              114
# 3                 no                  0              299.4               71
# 4                 no                  0              166.7              113
# 5                 no                  0              223.4               98
# 6                yes                 24              218.2               88
# 7                 no                  0              157.0               79
# 8                 no                  0              184.5               97
# 9                yes                 37              258.6               84
# 10                no                  0              129.1              137
# 11                no                  0              187.7              127
# 12                no                  0              128.8               96
# 13                no                  0              156.6               88
# 14                no                  0              120.7               70
# 15                no                  0              332.9               67
# 16               yes                 27              196.4              139
# 17                no                  0              190.7              114
# 18               yes                 33              189.7               66
# 19                no                  0              224.4               90
# 20                no                  0              155.1              117
# 21                no                  0               62.4               89
# 22                no                  0              183.0              112
# 23                no                  0              110.4              103
# 24                no                  0               81.1               86
# 25                no                  0              124.3               76
# 26               yes                 39              213.0              115
# 27                no                  0              134.3               73
# 28                no                  0              190.0              109
# 29                no                  0              119.3              117
# ...              ...                ...                ...              ...
# 3303             yes                 26              137.1               88
# 3304              no                  0              186.1              114
# 3305             yes                 22              224.1              127
# 3306             yes                 29               83.6              131
# 3307              no                  0              203.9              109
# 3308              no                  0              211.3               87
# 3309              no                  0              219.4              112
# 3310              no                  0              190.4               91
# 3311              no                  0              147.7               94
# 3312              no                  0              229.9              130
# 3313              no                  0              102.8              128
# 3314              no                  0              178.7               81
# 3315             yes                 18              148.5              106
# 3316             yes                 29              164.1              111
# 3317              no                  0              197.2               90
# 3318              no                  0              124.9              131
# 3319              no                  0              115.4               99
# 3320              no                  0              140.0              101
# 3321              no                  0              193.9              118
# 3322              no                  0              321.1              105
# 3323              no                  0              118.4              126
# 3324              no                  0              169.8              114
# 3325              no                  0              193.4               99
# 3326              no                  0              106.6              128
# 3327              no                  0              134.7               98
# 3328             yes                 36              156.2               77
# 3329              no                  0              231.1               57
# 3330              no                  0              180.8              109
# 3331              no                  0              213.8              105
# 3332             yes                 25              234.4              113
#
#       Total_Day_charge      ...        Total_Eve_Calls  Total_Eve_Charge  \
# 0                45.07      ...                     99             16.78
# 1                27.47      ...                    103             16.62
# 2                41.38      ...                    110             10.30
# 3                50.90      ...                     88              5.26
# 4                28.34      ...                    122             12.61
# 5                37.98      ...                    101             18.75
# 6                37.09      ...                    108             29.62
# 7                26.69      ...                     94              8.76
# 8                31.37      ...                     80             29.89
# 9                43.96      ...                    111             18.87
# 10               21.95      ...                     83             19.42
# 11               31.91      ...                    148             13.89
# 12               21.90      ...                     71              8.92
# 13               26.62      ...                     75             21.05
# 14               20.52      ...                     76             26.11
# 15               56.59      ...                     97             27.01
# 16               33.39      ...                     90             23.88
# 17               32.42      ...                    111             18.55
# 18               32.25      ...                     65             18.09
# 19               38.15      ...                     88             13.56
# 20               26.37      ...                     93             20.37
# 21               10.61      ...                    121             14.44
# 22               31.11      ...                     99              6.20
# 23               18.77      ...                    102             11.67
# 24               13.79      ...                     72             20.84
# 25               21.13      ...                    112             23.55
# 26               36.21      ...                    112             16.24
# 27               22.83      ...                    100             13.22
# 28               32.30      ...                     84             21.95
# 29               20.28      ...                    109             18.28
# ...                ...      ...                    ...               ...
# 3303             23.31      ...                    125             13.23
# 3304             31.64      ...                    140             16.88
# 3305             38.10      ...                     85             20.30
# 3306             14.21      ...                    131             17.33
# 3307             34.66      ...                    123             19.89
# 3308             35.92      ...                     97             14.08
# 3309             37.30      ...                    102             19.18
# 3310             32.37      ...                    107              7.82
# 3311             25.11      ...                     83             24.08
# 3312             39.08      ...                     93             12.27
# 3313             17.48      ...                     95             12.21
# 3314             30.38      ...                     74             19.86
# 3315             25.25      ...                    106              9.73
# 3316             27.90      ...                     96             18.62
# 3317             33.52      ...                    113             16.02
# 3318             21.23      ...                    118             25.54
# 3319             19.62      ...                    115             17.84
# 3320             23.80      ...                     77             16.69
# 3321             32.96      ...                    110              7.23
# 3322             54.59      ...                    122             22.57
# 3323             20.13      ...                     97             21.19
# 3324             28.87      ...                    105             16.80
# 3325             32.88      ...                     88              9.94
# 3326             18.12      ...                     87             24.21
# 3327             22.90      ...                     68             16.12
# 3328             26.55      ...                    126             18.32
# 3329             39.29      ...                     55             13.04
# 3330             30.74      ...                     58             24.55
# 3331             36.35      ...                     84             13.57
# 3332             39.85      ...                     82             22.60
#
#       Total_Night_Minutes  Total_Night_Calls  Total_Night_Charge  \
# 0                   244.7                 91               11.01
# 1                   254.4                103               11.45
# 2                   162.6                104                7.32
# 3                   196.9                 89                8.86
# 4                   186.9                121                8.41
# 5                   203.9                118                9.18
# 6                   212.6                118                9.57
# 7                   211.8                 96                9.53
# 8                   215.8                 90                9.71
# 9                   326.4                 97               14.69
# 10                  208.8                111                9.40
# 11                  196.0                 94                8.82
# 12                  141.1                128                6.35
# 13                  192.3                115                8.65
# 14                  203.0                 99                9.14
# 15                  160.6                128                7.23
# 16                   89.3                 75                4.02
# 17                  129.6                121                5.83
# 18                  165.7                108                7.46
# 19                  192.8                 74                8.68
# 20                  208.8                133                9.40
# 21                  209.6                 64                9.43
# 22                  181.8                 78                8.18
# 23                  189.6                105                8.53
# 24                  237.0                115               10.67
# 25                  250.7                115               11.28
# 26                  182.7                115                8.22
# 27                  102.1                 68                4.59
# 28                  181.5                102                8.17
# 29                  178.7                 90                8.04
# ...                   ...                ...                 ...
# 3303                247.6                 94               11.14
# 3304                206.5                 80                9.29
# 3305                174.2                 86                7.84
# 3306                229.5                 73               10.33
# 3307                160.7                 65                7.23
# 3308                265.9                 72               11.97
# 3309                255.3                 95               11.49
# 3310                224.8                108               10.12
# 3311                188.3                124                8.47
# 3312                262.4                110               11.81
# 3313                191.4                 97                8.61
# 3314                131.9                120                5.94
# 3315                178.3                 98                8.02
# 3316                220.3                108                9.91
# 3317                211.1                 94                9.50
# 3318                192.5                106                8.66
# 3319                280.9                112               12.64
# 3320                120.1                133                5.40
# 3321                210.1                134                9.45
# 3322                180.5                 72                8.12
# 3323                227.0                 56               10.22
# 3324                193.7                 82                8.72
# 3325                243.3                109               10.95
# 3326                178.9                 92                8.05
# 3327                221.4                128                9.96
# 3328                279.1                 83               12.56
# 3329                191.3                123                8.61
# 3330                191.9                 91                8.64
# 3331                139.2                137                6.26
# 3332                241.4                 77               10.86
#
#       Total_Intl_Minutes  Total_Intl_Calls  Total_Intl_Charge  No_CS_Calls  \
# 0                   10.0                 3               2.70            1
# 1                   13.7                 3               3.70            1
# 2                   12.2                 5               3.29            0
# 3                    6.6                 7               1.78            2
# 4                   10.1                 3               2.73            3
# 5                    6.3                 6               1.70            0
# 6                    7.5                 7               2.03            3
# 7                    7.1                 6               1.92            0
# 8                    8.7                 4               2.35            1
# 9                   11.2                 5               3.02            0
# 10                  12.7                 6               3.43            4
# 11                   9.1                 5               2.46            0
# 12                  11.2                 2               3.02            1
# 13                  12.3                 5               3.32            3
# 14                  13.1                 6               3.54            4
# 15                   5.4                 9               1.46            4
# 16                  13.8                 4               3.73            1
# 17                   8.1                 3               2.19            3
# 18                  10.0                 5               2.70            1
# 19                  13.0                 2               3.51            1
# 20                  10.6                 4               2.86            0
# 21                   5.7                 6               1.54            5
# 22                   9.5                19               2.57            0
# 23                   7.7                 6               2.08            2
# 24                  10.3                 2               2.78            0
# 25                  15.5                 5               4.19            3
# 26                   9.5                 3               2.57            0
# 27                  14.7                 4               3.97            3
# 28                   6.3                 6               1.70            0
# 29                  11.1                 1               3.00            1
# ...                  ...               ...                ...          ...
# 3303                11.5                 7               3.11            2
# 3304                13.8                 5               3.73            4
# 3305                11.5                 7               3.11            2
# 3306                 8.1                 3               2.19            1
# 3307                17.8                 4               4.81            4
# 3308                13.3                 6               3.59            1
# 3309                12.0                 4               3.24            4
# 3310                13.6                17               3.67            2
# 3311                 6.9                 5               1.86            2
# 3312                14.2                 4               3.83            2
# 3313                10.0                 5               2.70            1
# 3314                 9.1                 4               2.46            1
# 3315                 6.5                 4               1.76            0
# 3316                12.3                 9               3.32            0
# 3317                 7.8                 8               2.11            1
# 3318                11.6                 4               3.13            2
# 3319                15.9                 6               4.29            3
# 3320                 9.7                 4               2.62            4
# 3321                13.2                 8               3.56            3
# 3322                11.5                 2               3.11            4
# 3323                13.6                 3               3.67            5
# 3324                11.6                 4               3.13            1
# 3325                 9.3                 4               2.51            2
# 3326                14.9                 7               4.02            1
# 3327                11.8                 5               3.19            2
# 3328                 9.9                 6               2.67            2
# 3329                 9.6                 4               2.59            3
# 3330                14.1                 6               3.81            2
# 3331                 5.0                10               1.35            2
# 3332                13.7                 4               3.70            0
#
#       Customer_Left
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# 5             False
# 6             False
# 7             False
# 8             False
# 9             False
# 10             True
# 11            False
# 12            False
# 13            False
# 14            False
# 15             True
# 16            False
# 17            False
# 18            False
# 19            False
# 20            False
# 21             True
# 22            False
# 23            False
# 24            False
# 25            False
# 26            False
# 27            False
# 28            False
# 29            False
# ...             ...
# 3303          False
# 3304           True
# 3305          False
# 3306          False
# 3307          False
# 3308          False
# 3309          False
# 3310          False
# 3311          False
# 3312          False
# 3313          False
# 3314          False
# 3315          False
# 3316          False
# 3317          False
# 3318          False
# 3319          False
# 3320           True
# 3321          False
# 3322           True
# 3323           True
# 3324          False
# 3325          False
# 3326          False
# 3327          False
# 3328          False
# 3329          False
# 3330          False
# 3331          False
# 3332          False
#
# [3333 rows x 21 columns]

# %%
df['Customer_Left'] = df['Customer_Left'].astype('category')
df['Customer_Left'] = df['Customer_Left'].cat.codes

# %%
y = df["Customer_Left"]

# %%
df = df.drop(["Customer_Left","State"],axis = 1)

# %%
df["International_Plan"] = df["International_Plan"].astype("category")
df["International_Plan"] = df["International_Plan"].cat.codes

df["Voice_Mail_Plan"] = df["Voice_Mail_Plan"].astype("category")
df["Voice_Mail_Plan"] = df["Voice_Mail_Plan"].cat.codes

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(df,y,test_size = 0.3)

# %%
pcp = pcp(alpha = 0.1,n_iter = 10)

pcp.fit(x_train,y_train)

predictions_train = pcp.predict(x_train)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_train,predictions_train))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.86      1.00      0.92      2000
#           1       0.00      0.00      0.00       333
#
# avg / total       0.73      0.86      0.79      2333
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
